# %% [markdown]
# # ASSIGNMENT 3

# %% [markdown]
# # 1. Write a Python Program to Check if a Number is Positive, Negative or Zero?

# %%
num = int(input("Enter a number : "))

if num<0:
    print(num,"is Negative")
elif num==0:
    print(num,"is Zero")
else:
    print(num,"is positive")
# Out:
# Enter a number : 5
# 5 is positive

# %% [markdown]
# # 2. Write a Python Program to Check if a Number is Odd or Even?

# %%
num = int(input("Enter a number : "))

if num%2==0:
    print(num,"is Even")
else:
    print(num,"is Odd")
# Out:
# Enter a number : 8
# 8 is Even

# %% [markdown]
# # 3. Write a Python Program to Check Leap Year?

# %%
year = int(input("Enter a Year : "))

if year%4==0 and year%100!=0:
    print(year,"is Leap Year")
elif year%400 ==0 :
    print(year,"is Leap Year")
else:
    print(year,"is not a Leap year")
# Out:
# Enter a Year : 2016
# 2016 is Leap Year

# %% [markdown]
# # 4. Write a Python Program to Check Prime Number?

# %%
num = int(input("Enter a number : "))
count = 0
for i in range(1,num+1):
    if(num%i)==0:
        count = count +1 
        
if(count==2):
    print(num,"is Prime Number")
    
else:
    print(num,"is not a Prime number")
# Out:
# Enter a number : 43
# 43 is Prime Number

# %% [markdown]
# # 5. Write a Python Program to Print all Prime Numbers in an Interval of 1-10000?

# %%
for i in range(1,10000):
    count = 0
    for j in range(1,i+1):
        if(i%j)==0:
            count = count +1
    if(count==2):
        print(i,"is Prime Number")
# Out:
# 2 is Prime Number
# 3 is Prime Number
# 5 is Prime Number
# 7 is Prime Number
# 11 is Prime Number
# 13 is Prime Number
# 17 is Prime Number
# 19 is Prime Number
# 23 is Prime Number
# 29 is Prime Number
# 31 is Prime Number
# 37 is Prime Number
# 41 is Prime Number
# 43 is Prime Number
# 47 is Prime Number
# 53 is Prime Number
# 59 is Prime Number
# 61 is Prime Number
# 67 is Prime Number
# 71 is Prime Number
# 73 is Prime Number
# 79 is Prime Number
# 83 is Prime Number
# 89 is Prime Number
# 97 is Prime Number
# 101 is Prime Number
# 103 is Prime Number
# 107 is Prime Number
# 109 is Prime Number
# 113 is Prime Number
# 127 is Prime Number
# 131 is Prime Number
# 137 is Prime Number
# 139 is Prime Number
# 149 is Prime Number
# 151 is Prime Number
# 157 is Prime Number
# 163 is Prime Number
# 167 is Prime Number
# 173 is Prime Number
# 179 is Prime Number
# 181 is Prime Number
# 191 is Prime Number
# 193 is Prime Number
# 197 is Prime Number
# 199 is Prime Number
# 211 is Prime Number
# 223 is Prime Number
# 227 is Prime Number
# 229 is Prime Number
# 233 is Prime Number
# 239 is Prime Number
# 241 is Prime Number
# 251 is Prime Number
# 257 is Prime Number
# 263 is Prime Number
# 269 is Prime Number
# 271 is Prime Number
# 277 is Prime Number
# 281 is Prime Number
# 283 is Prime Number
# 293 is Prime Number
# 307 is Prime Number
# 311 is Prime Number
# 313 is Prime Number
# 317 is Prime Number
# 331 is Prime Number
# 337 is Prime Number
# 347 is Prime Number
# 349 is Prime Number
# 353 is Prime Number
# 359 is Prime Number
# 367 is Prime Number
# 373 is Prime Number
# 379 is Prime Number
# 383 is Prime Number
# 389 is Prime Number
# 397 is Prime Number
# 401 is Prime Number
# 409 is Prime Number
# 419 is Prime Number
# 421 is Prime Number
# 431 is Prime Number
# 433 is Prime Number
# 439 is Prime Number
# 443 is Prime Number
# 449 is Prime Number
# 457 is Prime Number
# 461 is Prime Number
# 463 is Prime Number
# 467 is Prime Number
# 479 is Prime Number
# 487 is Prime Number
# 491 is Prime Number
# 499 is Prime Number
# 503 is Prime Number
# 509 is Prime Number
# 521 is Prime Number
# 523 is Prime Number
# 541 is Prime Number
# 547 is Prime Number
# 557 is Prime Number
# 563 is Prime Number
# 569 is Prime Number
# 571 is Prime Number
# 577 is Prime Number
# 587 is Prime Number
# 593 is Prime Number
# 599 is Prime Number
# 601 is Prime Number
# 607 is Prime Number
# 613 is Prime Number
# 617 is Prime Number
# 619 is Prime Number
# 631 is Prime Number
# 641 is Prime Number
# 643 is Prime Number
# 647 is Prime Number
# 653 is Prime Number
# 659 is Prime Number
# 661 is Prime Number
# 673 is Prime Number
# 677 is Prime Number
# 683 is Prime Number
# 691 is Prime Number
# 701 is Prime Number
# 709 is Prime Number
# 719 is Prime Number
# 727 is Prime Number
# 733 is Prime Number
# 739 is Prime Number
# 743 is Prime Number
# 751 is Prime Number
# 757 is Prime Number
# 761 is Prime Number
# 769 is Prime Number
# 773 is Prime Number
# 787 is Prime Number
# 797 is Prime Number
# 809 is Prime Number
# 811 is Prime Number
# 821 is Prime Number
# 823 is Prime Number
# 827 is Prime Number
# 829 is Prime Number
# 839 is Prime Number
# 853 is Prime Number
# 857 is Prime Number
# 859 is Prime Number
# 863 is Prime Number
# 877 is Prime Number
# 881 is Prime Number
# 883 is Prime Number
# 887 is Prime Number
# 907 is Prime Number
# 911 is Prime Number
# 919 is Prime Number
# 929 is Prime Number
# 937 is Prime Number
# 941 is Prime Number
# 947 is Prime Number
# 953 is Prime Number
# 967 is Prime Number
# 971 is Prime Number
# 977 is Prime Number
# 983 is Prime Number
# 991 is Prime Number
# 997 is Prime Number
# 1009 is Prime Number
# 1013 is Prime Number
# 1019 is Prime Number
# 1021 is Prime Number
# 1031 is Prime Number
# 1033 is Prime Number
# 1039 is Prime Number
# 1049 is Prime Number
# 1051 is Prime Number
# 1061 is Prime Number
# 1063 is Prime Number
# 1069 is Prime Number
# 1087 is Prime Number
# 1091 is Prime Number
# 1093 is Prime Number
# 1097 is Prime Number
# 1103 is Prime Number
# 1109 is Prime Number
# 1117 is Prime Number
# 1123 is Prime Number
# 1129 is Prime Number
# 1151 is Prime Number
# 1153 is Prime Number
# 1163 is Prime Number
# 1171 is Prime Number
# 1181 is Prime Number
# 1187 is Prime Number
# 1193 is Prime Number
# 1201 is Prime Number
# 1213 is Prime Number
# 1217 is Prime Number
# 1223 is Prime Number
# 1229 is Prime Number
# 1231 is Prime Number
# 1237 is Prime Number
# 1249 is Prime Number
# 1259 is Prime Number
# 1277 is Prime Number
# 1279 is Prime Number
# 1283 is Prime Number
# 1289 is Prime Number
# 1291 is Prime Number
# 1297 is Prime Number
# 1301 is Prime Number
# 1303 is Prime Number
# 1307 is Prime Number
# 1319 is Prime Number
# 1321 is Prime Number
# 1327 is Prime Number
# 1361 is Prime Number
# 1367 is Prime Number
# 1373 is Prime Number
# 1381 is Prime Number
# 1399 is Prime Number
# 1409 is Prime Number
# 1423 is Prime Number
# 1427 is Prime Number
# 1429 is Prime Number
# 1433 is Prime Number
# 1439 is Prime Number
# 1447 is Prime Number
# 1451 is Prime Number
# 1453 is Prime Number
# 1459 is Prime Number
# 1471 is Prime Number
# 1481 is Prime Number
# 1483 is Prime Number
# 1487 is Prime Number
# 1489 is Prime Number
# 1493 is Prime Number
# 1499 is Prime Number
# 1511 is Prime Number
# 1523 is Prime Number
# 1531 is Prime Number
# 1543 is Prime Number
# 1549 is Prime Number
# 1553 is Prime Number
# 1559 is Prime Number
# 1567 is Prime Number
# 1571 is Prime Number
# 1579 is Prime Number
# 1583 is Prime Number
# 1597 is Prime Number
# 1601 is Prime Number
# 1607 is Prime Number
# 1609 is Prime Number
# 1613 is Prime Number
# 1619 is Prime Number
# 1621 is Prime Number
# 1627 is Prime Number
# 1637 is Prime Number
# 1657 is Prime Number
# 1663 is Prime Number
# 1667 is Prime Number
# 1669 is Prime Number
# 1693 is Prime Number
# 1697 is Prime Number
# 1699 is Prime Number
# 1709 is Prime Number
# 1721 is Prime Number
# 1723 is Prime Number
# 1733 is Prime Number
# 1741 is Prime Number
# 1747 is Prime Number
# 1753 is Prime Number
# 1759 is Prime Number
# 1777 is Prime Number
# 1783 is Prime Number
# 1787 is Prime Number
# 1789 is Prime Number
# 1801 is Prime Number
# 1811 is Prime Number
# 1823 is Prime Number
# 1831 is Prime Number
# 1847 is Prime Number
# 1861 is Prime Number
# 1867 is Prime Number
# 1871 is Prime Number
# 1873 is Prime Number
# 1877 is Prime Number
# 1879 is Prime Number
# 1889 is Prime Number
# 1901 is Prime Number
# 1907 is Prime Number
# 1913 is Prime Number
# 1931 is Prime Number
# 1933 is Prime Number
# 1949 is Prime Number
# 1951 is Prime Number
# 1973 is Prime Number
# 1979 is Prime Number
# 1987 is Prime Number
# 1993 is Prime Number
# 1997 is Prime Number
# 1999 is Prime Number
# 2003 is Prime Number
# 2011 is Prime Number
# 2017 is Prime Number
# 2027 is Prime Number
# 2029 is Prime Number
# 2039 is Prime Number
# 2053 is Prime Number
# 2063 is Prime Number
# 2069 is Prime Number
# 2081 is Prime Number
# 2083 is Prime Number
# 2087 is Prime Number
# 2089 is Prime Number
# 2099 is Prime Number
# 2111 is Prime Number
# 2113 is Prime Number
# 2129 is Prime Number
# 2131 is Prime Number
# 2137 is Prime Number
# 2141 is Prime Number
# 2143 is Prime Number
# 2153 is Prime Number
# 2161 is Prime Number
# 2179 is Prime Number
# 2203 is Prime Number
# 2207 is Prime Number
# 2213 is Prime Number
# 2221 is Prime Number
# 2237 is Prime Number
# 2239 is Prime Number
# 2243 is Prime Number
# 2251 is Prime Number
# 2267 is Prime Number
# 2269 is Prime Number
# 2273 is Prime Number
# 2281 is Prime Number
# 2287 is Prime Number
# 2293 is Prime Number
# 2297 is Prime Number
# 2309 is Prime Number
# 2311 is Prime Number
# 2333 is Prime Number
# 2339 is Prime Number
# 2341 is Prime Number
# 2347 is Prime Number
# 2351 is Prime Number
# 2357 is Prime Number
# 2371 is Prime Number
# 2377 is Prime Number
# 2381 is Prime Number
# 2383 is Prime Number
# 2389 is Prime Number
# 2393 is Prime Number
# 2399 is Prime Number
# 2411 is Prime Number
# 2417 is Prime Number
# 2423 is Prime Number
# 2437 is Prime Number
# 2441 is Prime Number
# 2447 is Prime Number
# 2459 is Prime Number
# 2467 is Prime Number
# 2473 is Prime Number
# 2477 is Prime Number
# 2503 is Prime Number
# 2521 is Prime Number
# 2531 is Prime Number
# 2539 is Prime Number
# 2543 is Prime Number
# 2549 is Prime Number
# 2551 is Prime Number
# 2557 is Prime Number
# 2579 is Prime Number
# 2591 is Prime Number
# 2593 is Prime Number
# 2609 is Prime Number
# 2617 is Prime Number
# 2621 is Prime Number
# 2633 is Prime Number
# 2647 is Prime Number
# 2657 is Prime Number
# 2659 is Prime Number
# 2663 is Prime Number
# 2671 is Prime Number
# 2677 is Prime Number
# 2683 is Prime Number
# 2687 is Prime Number
# 2689 is Prime Number
# 2693 is Prime Number
# 2699 is Prime Number
# 2707 is Prime Number
# 2711 is Prime Number
# 2713 is Prime Number
# 2719 is Prime Number
# 2729 is Prime Number
# 2731 is Prime Number
# 2741 is Prime Number
# 2749 is Prime Number
# 2753 is Prime Number
# 2767 is Prime Number
# 2777 is Prime Number
# 2789 is Prime Number
# 2791 is Prime Number
# 2797 is Prime Number
# 2801 is Prime Number
# 2803 is Prime Number
# 2819 is Prime Number
# 2833 is Prime Number
# 2837 is Prime Number
# 2843 is Prime Number
# 2851 is Prime Number
# 2857 is Prime Number
# 2861 is Prime Number
# 2879 is Prime Number
# 2887 is Prime Number
# 2897 is Prime Number
# 2903 is Prime Number
# 2909 is Prime Number
# 2917 is Prime Number
# 2927 is Prime Number
# 2939 is Prime Number
# 2953 is Prime Number
# 2957 is Prime Number
# 2963 is Prime Number
# 2969 is Prime Number
# 2971 is Prime Number
# 2999 is Prime Number
# 3001 is Prime Number
# 3011 is Prime Number
# 3019 is Prime Number
# 3023 is Prime Number
# 3037 is Prime Number
# 3041 is Prime Number
# 3049 is Prime Number
# 3061 is Prime Number
# 3067 is Prime Number
# 3079 is Prime Number
# 3083 is Prime Number
# 3089 is Prime Number
# 3109 is Prime Number
# 3119 is Prime Number
# 3121 is Prime Number
# 3137 is Prime Number
# 3163 is Prime Number
# 3167 is Prime Number
# 3169 is Prime Number
# 3181 is Prime Number
# 3187 is Prime Number
# 3191 is Prime Number
# 3203 is Prime Number
# 3209 is Prime Number
# 3217 is Prime Number
# 3221 is Prime Number
# 3229 is Prime Number
# 3251 is Prime Number
# 3253 is Prime Number
# 3257 is Prime Number
# 3259 is Prime Number
# 3271 is Prime Number
# 3299 is Prime Number
# 3301 is Prime Number
# 3307 is Prime Number
# 3313 is Prime Number
# 3319 is Prime Number
# 3323 is Prime Number
# 3329 is Prime Number
# 3331 is Prime Number
# 3343 is Prime Number
# 3347 is Prime Number
# 3359 is Prime Number
# 3361 is Prime Number
# 3371 is Prime Number
# 3373 is Prime Number
# 3389 is Prime Number
# 3391 is Prime Number
# 3407 is Prime Number
# 3413 is Prime Number
# 3433 is Prime Number
# 3449 is Prime Number
# 3457 is Prime Number
# 3461 is Prime Number
# 3463 is Prime Number
# 3467 is Prime Number
# 3469 is Prime Number
# 3491 is Prime Number
# 3499 is Prime Number
# 3511 is Prime Number
# 3517 is Prime Number
# 3527 is Prime Number
# 3529 is Prime Number
# 3533 is Prime Number
# 3539 is Prime Number
# 3541 is Prime Number
# 3547 is Prime Number
# 3557 is Prime Number
# 3559 is Prime Number
# 3571 is Prime Number
# 3581 is Prime Number
# 3583 is Prime Number
# 3593 is Prime Number
# 3607 is Prime Number
# 3613 is Prime Number
# 3617 is Prime Number
# 3623 is Prime Number
# 3631 is Prime Number
# 3637 is Prime Number
# 3643 is Prime Number
# 3659 is Prime Number
# 3671 is Prime Number
# 3673 is Prime Number
# 3677 is Prime Number
# 3691 is Prime Number
# 3697 is Prime Number
# 3701 is Prime Number
# 3709 is Prime Number
# 3719 is Prime Number
# 3727 is Prime Number
# 3733 is Prime Number
# 3739 is Prime Number
# 3761 is Prime Number
# 3767 is Prime Number
# 3769 is Prime Number
# 3779 is Prime Number
# 3793 is Prime Number
# 3797 is Prime Number
# 3803 is Prime Number
# 3821 is Prime Number
# 3823 is Prime Number
# 3833 is Prime Number
# 3847 is Prime Number
# 3851 is Prime Number
# 3853 is Prime Number
# 3863 is Prime Number
# 3877 is Prime Number
# 3881 is Prime Number
# 3889 is Prime Number
# 3907 is Prime Number
# 3911 is Prime Number
# 3917 is Prime Number
# 3919 is Prime Number
# 3923 is Prime Number
# 3929 is Prime Number
# 3931 is Prime Number
# 3943 is Prime Number
# 3947 is Prime Number
# 3967 is Prime Number
# 3989 is Prime Number
# 4001 is Prime Number
# 4003 is Prime Number
# 4007 is Prime Number
# 4013 is Prime Number
# 4019 is Prime Number
# 4021 is Prime Number
# 4027 is Prime Number
# 4049 is Prime Number
# 4051 is Prime Number
# 4057 is Prime Number
# 4073 is Prime Number
# 4079 is Prime Number
# 4091 is Prime Number
# 4093 is Prime Number
# 4099 is Prime Number
# 4111 is Prime Number
# 4127 is Prime Number
# 4129 is Prime Number
# 4133 is Prime Number
# 4139 is Prime Number
# 4153 is Prime Number
# 4157 is Prime Number
# 4159 is Prime Number
# 4177 is Prime Number
# 4201 is Prime Number
# 4211 is Prime Number
# 4217 is Prime Number
# 4219 is Prime Number
# 4229 is Prime Number
# 4231 is Prime Number
# 4241 is Prime Number
# 4243 is Prime Number
# 4253 is Prime Number
# 4259 is Prime Number
# 4261 is Prime Number
# 4271 is Prime Number
# 4273 is Prime Number
# 4283 is Prime Number
# 4289 is Prime Number
# 4297 is Prime Number
# 4327 is Prime Number
# 4337 is Prime Number
# 4339 is Prime Number
# 4349 is Prime Number
# 4357 is Prime Number
# 4363 is Prime Number
# 4373 is Prime Number
# 4391 is Prime Number
# 4397 is Prime Number
# 4409 is Prime Number
# 4421 is Prime Number
# 4423 is Prime Number
# 4441 is Prime Number
# 4447 is Prime Number
# 4451 is Prime Number
# 4457 is Prime Number
# 4463 is Prime Number
# 4481 is Prime Number
# 4483 is Prime Number
# 4493 is Prime Number
# 4507 is Prime Number
# 4513 is Prime Number
# 4517 is Prime Number
# 4519 is Prime Number
# 4523 is Prime Number
# 4547 is Prime Number
# 4549 is Prime Number
# 4561 is Prime Number
# 4567 is Prime Number
# 4583 is Prime Number
# 4591 is Prime Number
# 4597 is Prime Number
# 4603 is Prime Number
# 4621 is Prime Number
# 4637 is Prime Number
# 4639 is Prime Number
# 4643 is Prime Number
# 4649 is Prime Number
# 4651 is Prime Number
# 4657 is Prime Number
# 4663 is Prime Number
# 4673 is Prime Number
# 4679 is Prime Number
# 4691 is Prime Number
# 4703 is Prime Number
# 4721 is Prime Number
# 4723 is Prime Number
# 4729 is Prime Number
# 4733 is Prime Number
# 4751 is Prime Number
# 4759 is Prime Number
# 4783 is Prime Number
# 4787 is Prime Number
# 4789 is Prime Number
# 4793 is Prime Number
# 4799 is Prime Number
# 4801 is Prime Number
# 4813 is Prime Number
# 4817 is Prime Number
# 4831 is Prime Number
# 4861 is Prime Number
# 4871 is Prime Number
# 4877 is Prime Number
# 4889 is Prime Number
# 4903 is Prime Number
# 4909 is Prime Number
# 4919 is Prime Number
# 4931 is Prime Number
# 4933 is Prime Number
# 4937 is Prime Number
# 4943 is Prime Number
# 4951 is Prime Number
# 4957 is Prime Number
# 4967 is Prime Number
# 4969 is Prime Number
# 4973 is Prime Number
# 4987 is Prime Number
# 4993 is Prime Number
# 4999 is Prime Number
# 5003 is Prime Number
# 5009 is Prime Number
# 5011 is Prime Number
# 5021 is Prime Number
# 5023 is Prime Number
# 5039 is Prime Number
# 5051 is Prime Number
# 5059 is Prime Number
# 5077 is Prime Number
# 5081 is Prime Number
# 5087 is Prime Number
# 5099 is Prime Number
# 5101 is Prime Number
# 5107 is Prime Number
# 5113 is Prime Number
# 5119 is Prime Number
# 5147 is Prime Number
# 5153 is Prime Number
# 5167 is Prime Number
# 5171 is Prime Number
# 5179 is Prime Number
# 5189 is Prime Number
# 5197 is Prime Number
# 5209 is Prime Number
# 5227 is Prime Number
# 5231 is Prime Number
# 5233 is Prime Number
# 5237 is Prime Number
# 5261 is Prime Number
# 5273 is Prime Number
# 5279 is Prime Number
# 5281 is Prime Number
# 5297 is Prime Number
# 5303 is Prime Number
# 5309 is Prime Number
# 5323 is Prime Number
# 5333 is Prime Number
# 5347 is Prime Number
# 5351 is Prime Number
# 5381 is Prime Number
# 5387 is Prime Number
# 5393 is Prime Number
# 5399 is Prime Number
# 5407 is Prime Number
# 5413 is Prime Number
# 5417 is Prime Number
# 5419 is Prime Number
# 5431 is Prime Number
# 5437 is Prime Number
# 5441 is Prime Number
# 5443 is Prime Number
# 5449 is Prime Number
# 5471 is Prime Number
# 5477 is Prime Number
# 5479 is Prime Number
# 5483 is Prime Number
# 5501 is Prime Number
# 5503 is Prime Number
# 5507 is Prime Number
# 5519 is Prime Number
# 5521 is Prime Number
# 5527 is Prime Number
# 5531 is Prime Number
# 5557 is Prime Number
# 5563 is Prime Number
# 5569 is Prime Number
# 5573 is Prime Number
# 5581 is Prime Number
# 5591 is Prime Number
# 5623 is Prime Number
# 5639 is Prime Number
# 5641 is Prime Number
# 5647 is Prime Number
# 5651 is Prime Number
# 5653 is Prime Number
# 5657 is Prime Number
# 5659 is Prime Number
# 5669 is Prime Number
# 5683 is Prime Number
# 5689 is Prime Number
# 5693 is Prime Number
# 5701 is Prime Number
# 5711 is Prime Number
# 5717 is Prime Number
# 5737 is Prime Number
# 5741 is Prime Number
# 5743 is Prime Number
# 5749 is Prime Number
# 5779 is Prime Number
# 5783 is Prime Number
# 5791 is Prime Number
# 5801 is Prime Number
# 5807 is Prime Number
# 5813 is Prime Number
# 5821 is Prime Number
# 5827 is Prime Number
# 5839 is Prime Number
# 5843 is Prime Number
# 5849 is Prime Number
# 5851 is Prime Number
# 5857 is Prime Number
# 5861 is Prime Number
# 5867 is Prime Number
# 5869 is Prime Number
# 5879 is Prime Number
# 5881 is Prime Number
# 5897 is Prime Number
# 5903 is Prime Number
# 5923 is Prime Number
# 5927 is Prime Number
# 5939 is Prime Number
# 5953 is Prime Number
# 5981 is Prime Number
# 5987 is Prime Number
# 6007 is Prime Number
# 6011 is Prime Number
# 6029 is Prime Number
# 6037 is Prime Number
# 6043 is Prime Number
# 6047 is Prime Number
# 6053 is Prime Number
# 6067 is Prime Number
# 6073 is Prime Number
# 6079 is Prime Number
# 6089 is Prime Number
# 6091 is Prime Number
# 6101 is Prime Number
# 6113 is Prime Number
# 6121 is Prime Number
# 6131 is Prime Number
# 6133 is Prime Number
# 6143 is Prime Number
# 6151 is Prime Number
# 6163 is Prime Number
# 6173 is Prime Number
# 6197 is Prime Number
# 6199 is Prime Number
# 6203 is Prime Number
# 6211 is Prime Number
# 6217 is Prime Number
# 6221 is Prime Number
# 6229 is Prime Number
# 6247 is Prime Number
# 6257 is Prime Number
# 6263 is Prime Number
# 6269 is Prime Number
# 6271 is Prime Number
# 6277 is Prime Number
# 6287 is Prime Number
# 6299 is Prime Number
# 6301 is Prime Number
# 6311 is Prime Number
# 6317 is Prime Number
# 6323 is Prime Number
# 6329 is Prime Number
# 6337 is Prime Number
# 6343 is Prime Number
# 6353 is Prime Number
# 6359 is Prime Number
# 6361 is Prime Number
# 6367 is Prime Number
# 6373 is Prime Number
# 6379 is Prime Number
# 6389 is Prime Number
# 6397 is Prime Number
# 6421 is Prime Number
# 6427 is Prime Number
# 6449 is Prime Number
# 6451 is Prime Number
# 6469 is Prime Number
# 6473 is Prime Number
# 6481 is Prime Number
# 6491 is Prime Number
# 6521 is Prime Number
# 6529 is Prime Number
# 6547 is Prime Number
# 6551 is Prime Number
# 6553 is Prime Number
# 6563 is Prime Number
# 6569 is Prime Number
# 6571 is Prime Number
# 6577 is Prime Number
# 6581 is Prime Number
# 6599 is Prime Number
# 6607 is Prime Number
# 6619 is Prime Number
# 6637 is Prime Number
# 6653 is Prime Number
# 6659 is Prime Number
# 6661 is Prime Number
# 6673 is Prime Number
# 6679 is Prime Number
# 6689 is Prime Number
# 6691 is Prime Number
# 6701 is Prime Number
# 6703 is Prime Number
# 6709 is Prime Number
# 6719 is Prime Number
# 6733 is Prime Number
# 6737 is Prime Number
# 6761 is Prime Number
# 6763 is Prime Number
# 6779 is Prime Number
# 6781 is Prime Number
# 6791 is Prime Number
# 6793 is Prime Number
# 6803 is Prime Number
# 6823 is Prime Number
# 6827 is Prime Number
# 6829 is Prime Number
# 6833 is Prime Number
# 6841 is Prime Number
# 6857 is Prime Number
# 6863 is Prime Number
# 6869 is Prime Number
# 6871 is Prime Number
# 6883 is Prime Number
# 6899 is Prime Number
# 6907 is Prime Number
# 6911 is Prime Number
# 6917 is Prime Number
# 6947 is Prime Number
# 6949 is Prime Number
# 6959 is Prime Number
# 6961 is Prime Number
# 6967 is Prime Number
# 6971 is Prime Number
# 6977 is Prime Number
# 6983 is Prime Number
# 6991 is Prime Number
# 6997 is Prime Number
# 7001 is Prime Number
# 7013 is Prime Number
# 7019 is Prime Number
# 7027 is Prime Number
# 7039 is Prime Number
# 7043 is Prime Number
# 7057 is Prime Number
# 7069 is Prime Number
# 7079 is Prime Number
# 7103 is Prime Number
# 7109 is Prime Number
# 7121 is Prime Number
# 7127 is Prime Number
# 7129 is Prime Number
# 7151 is Prime Number
# 7159 is Prime Number
# 7177 is Prime Number
# 7187 is Prime Number
# 7193 is Prime Number
# 7207 is Prime Number
# 7211 is Prime Number
# 7213 is Prime Number
# 7219 is Prime Number
# 7229 is Prime Number
# 7237 is Prime Number
# 7243 is Prime Number
# 7247 is Prime Number
# 7253 is Prime Number
# 7283 is Prime Number
# 7297 is Prime Number
# 7307 is Prime Number
# 7309 is Prime Number
# 7321 is Prime Number
# 7331 is Prime Number
# 7333 is Prime Number
# 7349 is Prime Number
# 7351 is Prime Number
# 7369 is Prime Number
# 7393 is Prime Number
# 7411 is Prime Number
# 7417 is Prime Number
# 7433 is Prime Number
# 7451 is Prime Number
# 7457 is Prime Number
# 7459 is Prime Number
# 7477 is Prime Number
# 7481 is Prime Number
# 7487 is Prime Number
# 7489 is Prime Number
# 7499 is Prime Number
# 7507 is Prime Number
# 7517 is Prime Number
# 7523 is Prime Number
# 7529 is Prime Number
# 7537 is Prime Number
# 7541 is Prime Number
# 7547 is Prime Number
# 7549 is Prime Number
# 7559 is Prime Number
# 7561 is Prime Number
# 7573 is Prime Number
# 7577 is Prime Number
# 7583 is Prime Number
# 7589 is Prime Number
# 7591 is Prime Number
# 7603 is Prime Number
# 7607 is Prime Number
# 7621 is Prime Number
# 7639 is Prime Number
# 7643 is Prime Number
# 7649 is Prime Number
# 7669 is Prime Number
# 7673 is Prime Number
# 7681 is Prime Number
# 7687 is Prime Number
# 7691 is Prime Number
# 7699 is Prime Number
# 7703 is Prime Number
# 7717 is Prime Number
# 7723 is Prime Number
# 7727 is Prime Number
# 7741 is Prime Number
# 7753 is Prime Number
# 7757 is Prime Number
# 7759 is Prime Number
# 7789 is Prime Number
# 7793 is Prime Number
# 7817 is Prime Number
# 7823 is Prime Number
# 7829 is Prime Number
# 7841 is Prime Number
# 7853 is Prime Number
# 7867 is Prime Number
# 7873 is Prime Number
# 7877 is Prime Number
# 7879 is Prime Number
# 7883 is Prime Number
# 7901 is Prime Number
# 7907 is Prime Number
# 7919 is Prime Number
# 7927 is Prime Number
# 7933 is Prime Number
# 7937 is Prime Number
# 7949 is Prime Number
# 7951 is Prime Number
# 7963 is Prime Number
# 7993 is Prime Number
# 8009 is Prime Number
# 8011 is Prime Number
# 8017 is Prime Number
# 8039 is Prime Number
# 8053 is Prime Number
# 8059 is Prime Number
# 8069 is Prime Number
# 8081 is Prime Number
# 8087 is Prime Number
# 8089 is Prime Number
# 8093 is Prime Number
# 8101 is Prime Number
# 8111 is Prime Number
# 8117 is Prime Number
# 8123 is Prime Number
# 8147 is Prime Number
# 8161 is Prime Number
# 8167 is Prime Number
# 8171 is Prime Number
# 8179 is Prime Number
# 8191 is Prime Number
# 8209 is Prime Number
# 8219 is Prime Number
# 8221 is Prime Number
# 8231 is Prime Number
# 8233 is Prime Number
# 8237 is Prime Number
# 8243 is Prime Number
# 8263 is Prime Number
# 8269 is Prime Number
# 8273 is Prime Number
# 8287 is Prime Number
# 8291 is Prime Number
# 8293 is Prime Number
# 8297 is Prime Number
# 8311 is Prime Number
# 8317 is Prime Number
# 8329 is Prime Number
# 8353 is Prime Number
# 8363 is Prime Number
# 8369 is Prime Number
# 8377 is Prime Number
# 8387 is Prime Number
# 8389 is Prime Number
# 8419 is Prime Number
# 8423 is Prime Number
# 8429 is Prime Number
# 8431 is Prime Number
# 8443 is Prime Number
# 8447 is Prime Number
# 8461 is Prime Number
# 8467 is Prime Number
# 8501 is Prime Number
# 8513 is Prime Number
# 8521 is Prime Number
# 8527 is Prime Number
# 8537 is Prime Number
# 8539 is Prime Number
# 8543 is Prime Number
# 8563 is Prime Number
# 8573 is Prime Number
# 8581 is Prime Number
# 8597 is Prime Number
# 8599 is Prime Number
# 8609 is Prime Number
# 8623 is Prime Number
# 8627 is Prime Number
# 8629 is Prime Number
# 8641 is Prime Number
# 8647 is Prime Number
# 8663 is Prime Number
# 8669 is Prime Number
# 8677 is Prime Number
# 8681 is Prime Number
# 8689 is Prime Number
# 8693 is Prime Number
# 8699 is Prime Number
# 8707 is Prime Number
# 8713 is Prime Number
# 8719 is Prime Number
# 8731 is Prime Number
# 8737 is Prime Number
# 8741 is Prime Number
# 8747 is Prime Number
# 8753 is Prime Number
# 8761 is Prime Number
# 8779 is Prime Number
# 8783 is Prime Number
# 8803 is Prime Number
# 8807 is Prime Number
# 8819 is Prime Number
# 8821 is Prime Number
# 8831 is Prime Number
# 8837 is Prime Number
# 8839 is Prime Number
# 8849 is Prime Number
# 8861 is Prime Number
# 8863 is Prime Number
# 8867 is Prime Number
# 8887 is Prime Number
# 8893 is Prime Number
# 8923 is Prime Number
# 8929 is Prime Number
# 8933 is Prime Number
# 8941 is Prime Number
# 8951 is Prime Number
# 8963 is Prime Number
# 8969 is Prime Number
# 8971 is Prime Number
# 8999 is Prime Number
# 9001 is Prime Number
# 9007 is Prime Number
# 9011 is Prime Number
# 9013 is Prime Number
# 9029 is Prime Number
# 9041 is Prime Number
# 9043 is Prime Number
# 9049 is Prime Number
# 9059 is Prime Number
# 9067 is Prime Number
# 9091 is Prime Number
# 9103 is Prime Number
# 9109 is Prime Number
# 9127 is Prime Number
# 9133 is Prime Number
# 9137 is Prime Number
# 9151 is Prime Number
# 9157 is Prime Number
# 9161 is Prime Number
# 9173 is Prime Number
# 9181 is Prime Number
# 9187 is Prime Number
# 9199 is Prime Number
# 9203 is Prime Number
# 9209 is Prime Number
# 9221 is Prime Number
# 9227 is Prime Number
# 9239 is Prime Number
# 9241 is Prime Number
# 9257 is Prime Number
# 9277 is Prime Number
# 9281 is Prime Number
# 9283 is Prime Number
# 9293 is Prime Number
# 9311 is Prime Number
# 9319 is Prime Number
# 9323 is Prime Number
# 9337 is Prime Number
# 9341 is Prime Number
# 9343 is Prime Number
# 9349 is Prime Number
# 9371 is Prime Number
# 9377 is Prime Number
# 9391 is Prime Number
# 9397 is Prime Number
# 9403 is Prime Number
# 9413 is Prime Number
# 9419 is Prime Number
# 9421 is Prime Number
# 9431 is Prime Number
# 9433 is Prime Number
# 9437 is Prime Number
# 9439 is Prime Number
# 9461 is Prime Number
# 9463 is Prime Number
# 9467 is Prime Number
# 9473 is Prime Number
# 9479 is Prime Number
# 9491 is Prime Number
# 9497 is Prime Number
# 9511 is Prime Number
# 9521 is Prime Number
# 9533 is Prime Number
# 9539 is Prime Number
# 9547 is Prime Number
# 9551 is Prime Number
# 9587 is Prime Number
# 9601 is Prime Number
# 9613 is Prime Number
# 9619 is Prime Number
# 9623 is Prime Number
# 9629 is Prime Number
# 9631 is Prime Number
# 9643 is Prime Number
# 9649 is Prime Number
# 9661 is Prime Number
# 9677 is Prime Number
# 9679 is Prime Number
# 9689 is Prime Number
# 9697 is Prime Number
# 9719 is Prime Number
# 9721 is Prime Number
# 9733 is Prime Number
# 9739 is Prime Number
# 9743 is Prime Number
# 9749 is Prime Number
# 9767 is Prime Number
# 9769 is Prime Number
# 9781 is Prime Number
# 9787 is Prime Number
# 9791 is Prime Number
# 9803 is Prime Number
# 9811 is Prime Number
# 9817 is Prime Number
# 9829 is Prime Number
# 9833 is Prime Number
# 9839 is Prime Number
# 9851 is Prime Number
# 9857 is Prime Number
# 9859 is Prime Number
# 9871 is Prime Number
# 9883 is Prime Number
# 9887 is Prime Number
# 9901 is Prime Number
# 9907 is Prime Number
# 9923 is Prime Number
# 9929 is Prime Number
# 9931 is Prime Number
# 9941 is Prime Number
# 9949 is Prime Number
# 9967 is Prime Number
# 9973 is Prime Number
